# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

weather = pd.read_csv("data/KNYC.csv")
weather.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-0b17e0f1513e> in <module>
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5
# ----> 6 weather = pd.read_csv("data/KNYC.csv")
#       7 weather.head()
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'data/KNYC.csv' does not exist

# %% [markdown]
# We want to read in the `date` column in date format.

# %%
weather["date"] = pd.to_datetime(weather["date"])
weather.head()
# Out:
#         date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 0 2014-07-01                81               72               89
# 1 2014-07-02                82               72               91
# 2 2014-07-03                78               69               87
# 3 2014-07-04                70               65               74
# 4 2014-07-05                72               63               81
#
#    average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 0                68                83               52              100
# 1                68                83               56              100
# 2                68                83               54              103
# 3                68                84               55              102
# 4                68                84               53              101
#
#    record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 0                  1943                  1901                  0.00
# 1                  2001                  1966                  0.96
# 2                  1933                  1966                  1.78
# 3                  1986                  1949                  0.14
# 4                  1979                  1999                  0.00
#
#    average_precipitation  record_precipitation
# 0                   0.12                  2.17
# 1                   0.13                  1.79
# 2                   0.12                  2.80
# 3                   0.13                  1.76
# 4                   0.12                  3.07

# %%
weather.dtypes
# Out:
# date                     datetime64[ns]
# actual_mean_temp                  int64
# actual_min_temp                   int64
# actual_max_temp                   int64
# average_min_temp                  int64
# average_max_temp                  int64
# record_min_temp                   int64
# record_max_temp                   int64
# record_min_temp_year              int64
# record_max_temp_year              int64
# actual_precipitation            float64
# average_precipitation           float64
# record_precipitation            float64
# dtype: object

# %%
weather.tail()
# Out:
#           date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 360 2015-06-26                75               69               81
# 361 2015-06-27                65               58               71
# 362 2015-06-28                68               62               73
# 363 2015-06-29                70               63               76
# 364 2015-06-30                75               68               82
#
#      average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 360                67                82               56              100
# 361                67                82               55              101
# 362                67                83               54               96
# 363                67                83               52              101
# 364                67                83               53               99
#
#      record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 360                  1979                  1952                  0.00
# 361                  1940                  1966                  1.12
# 362                  1995                  1991                  0.29
# 363                  1919                  1934                  0.00
# 364                  1919                  1964                  0.00
#
#      average_precipitation  record_precipitation
# 360                   0.13                  4.29
# 361                   0.12                  2.11
# 362                   0.13                  1.69
# 363                   0.12                  2.57
# 364                   0.13                  3.07

# %% [markdown]
# It looks like we have a year's worth of weather data from July 1, 2014 to June 30, 2015.  See if there is any missing data.

# %%
weather.describe()
# Out:
#        actual_mean_temp  actual_min_temp  actual_max_temp  average_min_temp  \
# count        365.000000       365.000000       365.000000        365.000000
# mean          54.736986        47.246575        61.734247         48.016438
# std           18.679979        18.277156        19.446971         14.749176
# min           11.000000         2.000000        19.000000         27.000000
# 25%           39.000000        34.000000        44.000000         34.000000
# 50%           58.000000        50.000000        65.000000         48.000000
# 75%           72.000000        64.000000        80.000000         63.000000
# max           85.000000        77.000000        92.000000         69.000000
#
#        average_max_temp  record_min_temp  record_max_temp  \
# count        365.000000       365.000000       365.000000
# mean          62.079452        28.243836        83.731507
# std           16.068765        20.729107        13.351306
# min           38.000000       -15.000000        54.000000
# 25%           47.000000         8.000000        71.000000
# 50%           63.000000        31.000000        87.000000
# 75%           78.000000        47.000000        96.000000
# max           84.000000        59.000000       106.000000
#
#        record_min_temp_year  record_max_temp_year  actual_precipitation  \
# count            365.000000            365.000000            365.000000
# mean            1924.079452           1958.923288              0.126164
# std               38.000820             34.824357              0.325577
# min             1871.000000           1876.000000              0.000000
# 25%             1888.000000           1933.000000              0.000000
# 50%             1920.000000           1962.000000              0.000000
# 75%             1954.000000           1990.000000              0.050000
# max             2015.000000           2013.000000              2.540000
#
#        average_precipitation  record_precipitation
# count             365.000000            365.000000
# mean                0.136822              2.386137
# std                 0.015734              1.045702
# min                 0.100000              0.860000
# 25%                 0.130000              1.690000
# 50%                 0.140000              2.160000
# 75%                 0.150000              2.750000
# max                 0.170000              8.280000

# %% [markdown]
# Looking at the `count` row, we see there is no missing data.  `desribe()` also gives us the 5-number summary (min, 25 percentile, 50 percentile, 75 percentile, and max) for each numerical column, as well as the mean and standard deviation.
#
# Next, let's make some plots.  A line plot of the daily mean temperature.

# %%
weather.plot(x = "date", y= "actual_mean_temp")

# %% [markdown]
# Remember, our plots should always have a title and axis labels.

# %%
weather.plot(x = "date", y= "actual_mean_temp",legend = False)
plt.title("Daily mean temperature")
plt.xlabel("Date")
plt.ylabel('Mean temperature (F)')
# Out:
# Text(0,0.5,'Mean temperature (F)')

# %% [markdown]
# Suppose we want to look at the distribution of one of the columns.  We can make a histogram.

# %%
weather["actual_precipitation"].hist()

# %% [markdown]
# Sometimes it is helpful to have a finer breakdown of bins.  Also let's add a title and axis labels.

# %%
weather["actual_precipitation"].hist(bins = 20)
plt.title("Daily precipitation distribution")
plt.xlabel("Precipitation (inches)")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# We might also want to compare two columns using a *scatterplot*.  We can make a scatterplot of all possible pairs using the Seaborn package.

# %%
sns.pairplot(weather)

# %% [markdown]
# Or we can just make a single scatterplot.

# %%
weather.plot.scatter(x = "actual_mean_temp", y = "actual_precipitation")
plt.title("Relationship between daily mean temperature and precipitation")
plt.xlabel('Daily Mean Temperature (F)')
plt.ylabel('Daily Precipitation (inches)')
# Out:
# Text(0,0.5,'Daily Precipitation (inches)')

# %% [markdown]
# What about if we only want data for part of the year?  Then we need to *filter* our dataset.
#
# Let's find the distribution of daily temperatures in September.

# %%
sept_filter = weather["date"].dt.month == 9
weather[sept_filter]
# Out:
#          date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 62 2014-09-01                82               75               88
# 63 2014-09-02                85               77               92
# 64 2014-09-03                79               72               86
# 65 2014-09-04                78               69               87
# 66 2014-09-05                80               72               87
# 67 2014-09-06                79               67               91
# 68 2014-09-07                73               65               81
# 69 2014-09-08                70               65               75
# 70 2014-09-09                68               63               73
# 71 2014-09-10                72               63               80
# 72 2014-09-11                76               69               83
# 73 2014-09-12                70               62               78
# 74 2014-09-13                64               58               69
# 75 2014-09-14                62               53               71
# 76 2014-09-15                63               55               71
# 77 2014-09-16                64               58               70
# 78 2014-09-17                64               55               73
# 79 2014-09-18                67               57               76
# 80 2014-09-19                60               54               66
# 81 2014-09-20                66               57               75
# 82 2014-09-21                71               67               75
# 83 2014-09-22                63               55               71
# 84 2014-09-23                62               52               71
# 85 2014-09-24                65               58               71
# 86 2014-09-25                61               57               64
# 87 2014-09-26                68               58               77
# 88 2014-09-27                72               60               83
# 89 2014-09-28                74               64               84
# 90 2014-09-29                73               67               79
# 91 2014-09-30                67               62               71
#
#     average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 62                66                80               51               97
# 63                65                80               51              102
# 64                65                80               50               99
# 65                65                79               47               97
# 66                64                79               51               94
# 67                64                79               48               97
# 68                64                78               46              101
# 69                64                78               54               93
# 70                63                78               48               94
# 71                63                77               43               97
# 72                63                77               43               99
# 73                62                77               46               94
# 74                62                76               46               94
# 75                62                76               46               93
# 76                61                76               45               92
# 77                61                75               47               93
# 78                61                75               45               93
# 79                60                75               44               91
# 80                60                74               44               94
# 81                59                74               44               93
# 82                59                73               40               95
# 83                59                73               41               95
# 84                58                73               41               97
# 85                58                72               40               89
# 86                57                72               40               90
# 87                57                71               42               91
# 88                57                71               41               90
# 89                56                70               41               88
# 90                56                70               42               88
# 91                55                70               39               89
#
#     record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 62                  1872                  1953                  0.00
# 63                  1886                  1953                  0.00
# 64                  1893                  1929                  0.00
# 65                  1883                  1929                  0.00
# 66                  1963                  1985                  0.00
# 67                  1924                  1881                  0.11
# 68                  1888                  1881                  0.00
# 69                  1955                  1919                  0.00
# 70                  1883                  1915                  0.00
# 71                  1883                  1983                  0.00
# 72                  1917                  1983                  0.00
# 73                  1917                  1961                  0.00
# 74                  1963                  1952                  0.26
# 75                  1975                  1931                  0.00
# 76                  1913                  1927                  0.00
# 77                  1966                  1915                  0.37
# 78                  1986                  1991                  0.00
# 79                  1990                  1891                  0.00
# 80                  1929                  1983                  0.00
# 81                  1993                  1983                  0.00
# 82                  1871                  1895                  0.15
# 83                  1904                  1914                  0.00
# 84                  1947                  1895                  0.00
# 85                  1963                  1959                  0.00
# 86                  1887                  1970                  0.32
# 87                  1940                  1970                  0.00
# 88                  1957                  1933                  0.00
# 89                  1947                  1881                  0.00
# 90                  1942                  1945                  0.00
# 91                  1912                  1986                  0.00
#
#     average_precipitation  record_precipitation
# 62                   0.13                  3.84
# 63                   0.13                  2.12
# 64                   0.13                  3.32
# 65                   0.14                  3.48
# 66                   0.13                  2.45
# 67                   0.13                  3.26
# 68                   0.14                  2.07
# 69                   0.13                  4.86
# 70                   0.13                  0.86
# 71                   0.13                  1.38
# 72                   0.13                  2.90
# 73                   0.14                  2.35
# 74                   0.14                  3.94
# 75                   0.14                  3.82
# 76                   0.15                  4.16
# 77                   0.15                  5.02
# 78                   0.15                  3.37
# 79                   0.15                  3.92
# 80                   0.15                  4.30
# 81                   0.15                  2.32
# 82                   0.15                  5.54
# 83                   0.15                  2.34
# 84                   0.14                  8.28
# 85                   0.15                  2.26
# 86                   0.14                  2.36
# 87                   0.15                  2.34
# 88                   0.15                  3.13
# 89                   0.16                  3.84
# 90                   0.16                  2.18
# 91                   0.16                  2.64

# %%
weather[sept_filter]["actual_mean_temp"].hist()
plt.title("Distribution of mean temperature in September 2014")
plt.xlabel("Temperature (F)")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# See https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#time-date-components for the different properties that can be used after dt.  For example to get the mean min temperatures on all Tuesdays:

# %%
tues_filter = weather["date"].dt.dayofweek == 1
weather[tues_filter]["actual_min_temp"].mean()
# Out:
# 49.22641509433962

# %%
aug_filter = weather["date"].dt.month == 8
weather[aug_filter]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d91d5f3030a9> in <module>
# ----> 1 aug_filter = weather["date"].dt.month == 8
#       2 weather[aug_filter]
#
# NameError: name 'weather' is not defined
